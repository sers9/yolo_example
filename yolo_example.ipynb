# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
img = 'https://ultralytics.com/images/zidane.jpg'

# Inference
results = model(img)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /home/master/.cache/torch/hub/master.zip
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...
# YOLOv5 🚀 2021-5-27 torch 1.8.1+cu102 CUDA:0 (GeForce GTX 1070, 8117.1875MB)

# %%
results

# %%
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 10504.2ms pre-process, 15.4ms inference, 2.2ms NMS per image at shape (1, 3, 384, 640)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F95E52283D0>

# %% [markdown]
# ## Cell phone images

# %%
import os
img_files = os.listdir('./images')

# %%
import cv2
import torch
from PIL import Image

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
# for f in img_files:
#     torch.hub.download_url_to_file('./images/' + f, f)  # download 2 images
# img1 = Image.open('zidane.jpg')  # PIL image
# img2 = cv2.imread('bus.jpg')[:, :, ::-1]  # OpenCV image (BGR to RGB)
# imgs = [img1, img2]  # batch of images

imgs = []
for f in img_files:
    imgs.append(Image.open(f'./images/{f}'))
    

# Inference
results = model(imgs, size=640)  # includes NMS

# Results
results.print()  
results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 1  433.50  433.50   517.5  714.5    0.687988     27     tie
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# Using cache found in /home/master/.cache/torch/hub/ultralytics_yolov5_master
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...
# YOLOv5 🚀 2021-5-27 torch 1.8.1+cu102 CUDA:0 (GeForce GTX 1070, 8117.1875MB)
# image 1/9: 267x400 1 cell phone
# image 2/9: 267x400 1 cell phone
# image 3/9: 400x267 1 person, 1 cup
# image 4/9: 400x320 1 person, 1 cell phone
# image 5/9: 400x320 1 potted plant, 1 mouse, 2 keyboards, 1 cell phone
# image 6/9: 400x267 1 remote, 1 cell phone
# image 7/9: 400x279 1 person
# image 8/9: 400x320 1 person, 1 cell phone
# image 9/9: 267x400 1 person, 1 cell phone
# Speed: 18.0ms pre-process, 13.4ms inference, 0.9ms NMS per image at shape (9, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=400x267 at 0x7F95CC5B2BE0>
# <PIL.Image.Image image mode=RGB size=400x267 at 0x7F9528DA48B0>
# <PIL.Image.Image image mode=RGB size=267x400 at 0x7F95CC7CAFA0>
# <PIL.Image.Image image mode=RGB size=320x400 at 0x7F95CC758D60>
# <PIL.Image.Image image mode=RGB size=320x400 at 0x7F952901F1F0>
# <PIL.Image.Image image mode=RGB size=267x400 at 0x7F9528DA48B0>
# <PIL.Image.Image image mode=RGB size=279x400 at 0x7F95CC758D60>
# <PIL.Image.Image image mode=RGB size=320x400 at 0x7F952901F1F0>
# <PIL.Image.Image image mode=RGB size=400x267 at 0x7F9528DA48B0>
#        xmin       ymin      xmax     ymax  confidence  class        name
# 0  139.0625  19.671875  267.1875  251.625    0.722168     67  cell phone
